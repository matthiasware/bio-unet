# %%
from keras.models import load_model
import pickle
import splitdata
import os
import preprocess
import numpy as np
import preprocess
from model_03 import get_model
import splitdata
from keras.models import Model
from keras.layers.merge import concatenate
from keras.layers import Conv2D, MaxPooling2D, Input, Conv2DTranspose

# %%
model = get_model(512, 1)
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_14 (InputLayer)           (None, 512, 512, 3)  0
# __________________________________________________________________________________________________
# conv_1_1 (Conv2D)               (None, 512, 512, 1)  28          input_14[0][0]
# __________________________________________________________________________________________________
# conv_2_2 (Conv2D)               (None, 512, 512, 1)  10          conv_1_1[0][0]
# __________________________________________________________________________________________________
# pool_1 (MaxPooling2D)           (None, 256, 256, 1)  0           conv_2_2[0][0]
# __________________________________________________________________________________________________
# conv2_1 (Conv2D)                (None, 256, 256, 2)  20          pool_1[0][0]
# __________________________________________________________________________________________________
# conv2_2 (Conv2D)                (None, 256, 256, 2)  38          conv2_1[0][0]
# __________________________________________________________________________________________________
# pool_2 (MaxPooling2D)           (None, 128, 128, 2)  0           conv2_2[0][0]
# __________________________________________________________________________________________________
# conv_3_1 (Conv2D)               (None, 128, 128, 4)  76          pool_2[0][0]
# __________________________________________________________________________________________________
# conv_3_2 (Conv2D)               (None, 128, 128, 4)  148         conv_3_1[0][0]
# __________________________________________________________________________________________________
# pool_3 (MaxPooling2D)           (None, 64, 64, 4)    0           conv_3_2[0][0]
# __________________________________________________________________________________________________
# conv_4_1 (Conv2D)               (None, 64, 64, 8)    296         pool_3[0][0]
# __________________________________________________________________________________________________
# conv_4_2 (Conv2D)               (None, 64, 64, 8)    584         conv_4_1[0][0]
# __________________________________________________________________________________________________
# pool_4 (MaxPooling2D)           (None, 32, 32, 8)    0           conv_4_2[0][0]
# __________________________________________________________________________________________________
# conv_5_1 (Conv2D)               (None, 32, 32, 16)   1168        pool_4[0][0]
# __________________________________________________________________________________________________
# conv_5_2 (Conv2D)               (None, 32, 32, 16)   2320        conv_5_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_53 (Conv2DTran (None, 64, 64, 8)    1160        conv_5_2[0][0]
# __________________________________________________________________________________________________
# conc_5_4 (Concatenate)          (None, 64, 64, 16)   0           conv2d_transpose_53[0][0]
#                                                                  conv_4_2[0][0]
# __________________________________________________________________________________________________
# conv_6_1 (Conv2D)               (None, 64, 64, 8)    1160        conc_5_4[0][0]
# __________________________________________________________________________________________________
# conv_6_2 (Conv2D)               (None, 64, 64, 8)    584         conv_6_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_54 (Conv2DTran (None, 128, 128, 4)  292         conv_6_2[0][0]
# __________________________________________________________________________________________________
# conc_6_3 (Concatenate)          (None, 128, 128, 8)  0           conv2d_transpose_54[0][0]
#                                                                  conv_3_2[0][0]
# __________________________________________________________________________________________________
# conv_7_1 (Conv2D)               (None, 128, 128, 4)  292         conc_6_3[0][0]
# __________________________________________________________________________________________________
# conv_7_2 (Conv2D)               (None, 128, 128, 4)  148         conv_7_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_55 (Conv2DTran (None, 256, 256, 2)  74          conv_7_2[0][0]
# __________________________________________________________________________________________________
# conc_7_2 (Concatenate)          (None, 256, 256, 4)  0           conv2d_transpose_55[0][0]
#                                                                  conv2_2[0][0]
# __________________________________________________________________________________________________
# conv_8_1 (Conv2D)               (None, 256, 256, 2)  74          conc_7_2[0][0]
# __________________________________________________________________________________________________
# conv_8_2 (Conv2D)               (None, 256, 256, 2)  38          conv_8_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_56 (Conv2DTran (None, 512, 512, 1)  19          conv_8_2[0][0]
# __________________________________________________________________________________________________
# conc_8_1 (Concatenate)          (None, 512, 512, 2)  0           conv2d_transpose_56[0][0]
#                                                                  conv_2_2[0][0]
# __________________________________________________________________________________________________
# conv_9_1 (Conv2D)               (None, 512, 512, 1)  19          conc_8_1[0][0]
# __________________________________________________________________________________________________
# conv_9_2 (Conv2D)               (None, 512, 512, 1)  10          conv_9_1[0][0]
# __________________________________________________________________________________________________
# conv_10 (Conv2D)                (None, 512, 512, 1)  2           conv_9_2[0][0]
# ==================================================================================================
# Total params: 8,560
# Trainable params: 8,560
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
x = np.zeros((10, 8, 5))

# %%
idx = (slice(0, 4, 1), slice(2,2,1), slice(2,2,1))

# %%
x[idx]
# Out:
# array([], shape=(4, 0, 0), dtype=float64)
